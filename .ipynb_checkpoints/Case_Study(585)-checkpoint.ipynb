# %% [markdown]
# # DATA ANALYTICS CASE_STUDY --> 1

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # V. Aditya Bharadwaj
# # 2211CS010585
# # Group:3, CSE.

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Importing datasets and assigning variable

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("class_marks.csv")


df = df.fillna(0) 
df = df.astype(int)
df['Grade'] = df['Total'].apply(lambda x: 
                                'A' if x >= 36 else 
                               ('B' if x >= 32 else 
                               ('C' if x >= 28 else 
                                'D' if x >= 24 else 'E')))

df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37      4      5      6      4      2      1      0      5      8
# 1      32      4      3      4      3      0      0      3      6      9
# 2      33      4      5      5      1      5      5      0      0      8
# 3      24      4      6      6      3      2      2      0      0      0
# 4      36      3      6      4      4      5      4      0      0     10
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32      3      6      3      4      5      3      0      0      0
# 82     27      2      2      5      3      0      0      0      0      7
# 83     37      4      6      6      2      0      0      0      0      9
# 84     28      4      0      5      4      5      4      0      0      6
# 85     29      4      6      0      0      0      0      3      5      7
#
#     Q6aM4  Q6bM6 Grade
# 0       4      6     A
# 1       0      0     B
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("class_marks.csv")
df = df.fillna(0) 
df = df.astype(int)
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37      4      5      6      4      2      1      0      5      8
# 1      32      4      3      4      3      0      0      3      6      9
# 2      33      4      5      5      1      5      5      0      0      8
# 3      24      4      6      6      3      2      2      0      0      0
# 4      36      3      6      4      4      5      4      0      0     10
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32      3      6      3      4      5      3      0      0      0
# 82     27      2      2      5      3      0      0      0      0      7
# 83     37      4      6      6      2      0      0      0      0      9
# 84     28      4      0      5      4      5      4      0      0      6
# 85     29      4      6      0      0      0      0      3      5      7
#
#     Q6aM4  Q6bM6
# 0       4      6
# 1       0      0
# 2       0      0
# 3       2      0
# ...

# %% [markdown]
# Sorting the DataFrame in ascending order based on the "Total" column and storing the result in cr

# %%
cr=df.sort_values("Total",ascending=True)
cr
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 69      3      1      0      1      0      0      0      1      0      0
# 11      8      2      2      0      3      1      0      0      0      0
# 23      9      4      3      0      0      0      0      0      0      0
# 22     14      4      4      5      2      0      0      0      0      0
# 57     17      3      0      0      4      0      0      3      7      0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 73     40      4      6      0      0      5      5      3      0     10
# 53     40      4      6      6      4      5      5      0      0     10
# 51     40      0      0      6      4      0      0      3      7     10
# 33     40      0      0      6      4      5      5      3      7      0
# 65     40      4      6      6      4      5      5      0      0     10
#
#     Q6aM4  Q6bM6 Grade
# 69      0      0     E
# 11      0      0     E
# ...

# %% [markdown]
# Total values are sorted in ascending order above.

# %%
cr['Q1']=cr['Q1aM4']+cr['Q1bM6']
cr['Q2']=cr['Q2aM6']+cr['Q2bM4']
cr['Q3']=cr['Q3aM5']+cr['Q3bM5']
cr['Q4']=cr['Q4aM3']+cr['Q4bM7']
cr['Q5']=cr['Q5M10']
cr['Q6']=cr['Q6aM4']+cr['Q6bM6']
cr
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 69      3      1      0      1      0      0      0      1      0      0
# 11      8      2      2      0      3      1      0      0      0      0
# 23      9      4      3      0      0      0      0      0      0      0
# 22     14      4      4      5      2      0      0      0      0      0
# 57     17      3      0      0      4      0      0      3      7      0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 73     40      4      6      0      0      5      5      3      0     10
# 53     40      4      6      6      4      5      5      0      0     10
# 51     40      0      0      6      4      0      0      3      7     10
# 33     40      0      0      6      4      5      5      3      7      0
# 65     40      4      6      6      4      5      5      0      0     10
#
#     Q6aM4  Q6bM6 Grade  Q1  Q2  Q3  Q4  Q5  Q6
# ...

# %% [markdown]
# New Column added as Grade.., to verify grades of student's grade

# %%
import pandas as pd

df['Grade'] = df['Total'].apply(lambda x: 
                                'A' if x >= 36 else 
                               ('B' if x >= 32 else 
                               ('C' if x >= 28 else 
                                'D' if x >= 24 else 'E')))
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37      4      5      6      4      2      1      0      5      8
# 1      32      4      3      4      3      0      0      3      6      9
# 2      33      4      5      5      1      5      5      0      0      8
# 3      24      4      6      6      3      2      2      0      0      0
# 4      36      3      6      4      4      5      4      0      0     10
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32      3      6      3      4      5      3      0      0      0
# 82     27      2      2      5      3      0      0      0      0      7
# 83     37      4      6      6      2      0      0      0      0      9
# 84     28      4      0      5      4      5      4      0      0      6
# 85     29      4      6      0      0      0      0      3      5      7
#
#     Q6aM4  Q6bM6 Grade
# 0       4      6     A
# 1       0      0     B
# ...

# %%
df[df['Grade'] == 'A'].shape[0]
# Out:
# 23

# %% [markdown]
#  New Columns Q1, Q2, Q3, Q4, Q5 and Q6 are created above to do analysis.

# %%
s=cr.loc[(cr['Total'] >= 15) & (cr['Total'] <= 20)]
s=s.reset_index()
s
# Out:
#    index  Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  \
# 0     57     17      3      0      0      4      0      0      3      7
# 1     76     17      2      3      4      2      4      2      0      0
# 2     63     18      4      0      4      2      0      0      0      0
# 3     34     19      2      3      3      1      2      3      0      0
# 4     68     20      4      6      6      4      0      0      0      0
# 5      5     20      4      6      6      4      0      0      0      0
# 6     60     20      2      5      3      2      0      0      0      0
# 7     30     20      4      4      4      4      5      0      0      0
#
#    Q5M10  Q6aM4  Q6bM6 Grade  Q1  Q2  Q3  Q4  Q5  Q6
# 0      0      4      0     E   3   4   0  10   0   4
# 1      0      0      0     E   5   6   6   0   0   0
# 2      8      0      0     E   4   6   0   0   8   0
# 3      5      0      0     E   5   4   5   0   5   0
# ...

# %% [markdown]
# # Total marks between 15-20 is filtered above under a variable "s"

# %%
a1=s.groupby('Q1')['Total']
a1.hist(color = 'red',figsize=[8,8],grid=False,bins=5)
plt.title("Histogram of students who scored 15-20 Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q1")
plt.show()

# %% [markdown]
#  Most of the students scored 1 mark and maximum mark is 2, implying that all the students in this range secured very less marks in Q1

# %%
a2=s.groupby('Q2')['Total']
a2.hist(color = 'red',figsize=[8,8],grid=False,bins=5)
plt.title("Histogram of students who scored 15-20 Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q2")
plt.show()

# %% [markdown]
#  Very few students got high marks in Q2 and that's only 2, so overall performance in Q2 is not upto the mark

# %%
a3=s.groupby('Q3')['Total']
a3.hist(color = 'red',figsize=[8,8],grid=False,bins=5)
plt.title("Histogram of students who scored 15-20 Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q3")
plt.show()

# %% [markdown]
# Most of the students scoring very few marks in Q3, implying that all the students in this range secured very less marks in Q3.

# %%
a4=s.groupby('Q4')['Total']
a4.hist(color = 'red',figsize=[8,8],grid=False,bins=5)
plt.title("Histogram of students who scored 15-20 Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q4")
plt.show()

# %% [markdown]
# The majority of students scored very low marks in Q4, implying that all the students in this range secured very less marks in Q4.

# %%
a5=s.groupby('Q5')['Total']
a5.hist(color = 'red',figsize=[8,8],grid=False,bins=5)
plt.title("Histogram of students who scored 15-20 Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q5")
plt.show()

# %% [markdown]
# The majority of students scored very low marks in Q5, implying that all the students in this range secured very less marks in Q5

# %%
a6=s.groupby('Q6')['Total']
a6.hist(color='orange',figsize=[8,8],grid=False,bins=8)
plt.title("Histogram of students who scored 15-20 Total Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q6")
plt.show()

# %% [markdown]
# None of the students form the filter data are attempted Q6.

# %%
c=cr.loc[(cr['Total'] >= 20) & (cr['Total'] <= 25)]
c=c.reset_index()
c
# Out:
#     index  Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  \
# 0      68     20      4      6      6      4      0      0      0      0
# 1       5     20      4      6      6      4      0      0      0      0
# 2      60     20      2      5      3      2      0      0      0      0
# 3      30     20      4      4      4      4      5      0      0      0
# 4      54     21      2      6      0      0      5      5      3      0
# 5      75     21      4      0      6      1      1      1      0      0
# 6      77     22      4      5      0      0      3      2      2      0
# 7      39     22      3      2      0      1      3      3      0      0
# 8      25     22      4      2      5      2      4      3      2      0
# 9      61     24      4      5      6      4      0      5      0      0
# 10     18     24      3      3      5      3      0      0      2      1
# 11     50     24      4      5      0      0      5      5      0      0
# ...

# %% [markdown]
# Total marks 20-25 is filtered from the data set above under a variable "c"

# %%
c.plot.scatter(x='Q1',y='Total',color='red',s=40)
plt.title("20-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# The points on the scatter plot indicate that students scoring higher in Q1 generally tend to have higher total marks within this range.

# %%
c.plot.scatter(x='Q2',y='Total',color='red',s=40)
plt.title("20-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# The points on the scatter plot indicate that students scoring moderate in Q3 generally 3 student have got highest mark in Q3.

# %%
c.plot.scatter(x='Q4',y='Total',color='red',s=40)
plt.title("20-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# The points on the scatter plot indicate that students scoring moderate in Q4 only 3 students have attempted the question Q4.

# %%
c.plot.scatter(x='Q5',y='Total',color='red',s=40)
plt.title("20-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# No student have got full marks in this question Q5, and most of the students obtained 8 Marks.

# %%
c.plot.scatter(x='Q6',y='Total',color='red',s=40)
plt.title("20-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# Only two students obtained full marks(10M) in th Q6.

# %%
d=cr.loc[(cr['Total'] >= 25) & (cr['Total'] <= 30)]
d=d.reset_index()
d
# Out:
#     index  Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  \
# 0      72     25      2      0      4      4      0      5      3      7
# 1      48     25      2      6      0      0      0      0      3      6
# 2       6     25      3      4      0      2      5      5      0      0
# 3      74     25      1      5      6      4      0      0      0      0
# 4      41     26      2      3      4      3      4      3      0      3
# 5      19     26      3      0      6      4      0      2      2      1
# 6      31     26      3      4      6      2      2      0      1      0
# 7       8     27      3      5      5      0      0      0      0      0
# 8      79     27      2      6      0      3      2      5      0      0
# 9      29     27      4      0      6      1      0      0      0      7
# 10     82     27      2      2      5      3      0      0      0      0
# 11     38     28      4      5      6      4      5      3      1      0
# ...

# %% [markdown]
# Total marks 20-25 is filtered from the data set above under a variable "d"

# %%
d.boxplot(by='Q1', column =['Total'], grid = False,color='red',figsize=[5,6])
plt.title("25-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Most of the students obtained 10 marks in Q2

# %%
d.boxplot(by='Q3', column =['Total'], grid = False,color='red',figsize=[5,6])
plt.title("25-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Most of the students obtained 8 marks in Q1

# %%
d.boxplot(by='Q2', column =['Total'], grid = False,color='red',figsize=[5,6])
plt.title("25-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Most of the students obtained 10 marks in Q2.

# %%
d.boxplot(by='Q3', column =['Total'], grid = False,color='red',figsize=[7,5])
plt.title("25-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Most of the students obtained 9 marks in Q4

# %%
d.boxplot(by='Q5', column =['Total'], grid = False,color='red',figsize=[5,6])
plt.title("25-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Most Students obtained marks between 4-9, but only 1 student obtained 10 marks.

# %%
d.boxplot(by='Q6', column =['Total'], grid = False,color='red',figsize=[5,6])
plt.title("25-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Most of the students obtained 8 marks in Q1, whereas not even a single student reached the 10 marks.

# %%
m=cr.loc[(cr['Total']>=30) & (cr['Total']<=35)]
m=m.reset_index()
m
# Out:
#     index  Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  \
# 0      35     30      4      6      6      4      0      1      0      0
# 1      14     30      4      6      6      2      4      5      3      0
# 2      16     30      4      0      6      4      5      2      0      0
# 3      80     31      4      6      6      2      2      5      0      0
# 4      66     31      4      5      5      2      5      3      1      5
# 5      37     31      4      4      6      4      0      0      0      0
# 6       1     32      4      3      4      3      0      0      3      6
# 7      15     32      3      0      2      1      5      5      3      7
# 8      27     32      2      6      6      1      5      5      3      3
# 9      13     32      3      3      6      4      3      5      0      0
# 10     32     32      4      6      6      4      2      0      0      0
# 11     81     32      3      6      3      4      5      3      0      0
# ...

# %% [markdown]
# Total marks 30-35 is filtered from the data set above under a variable "m".

# %%
m.plot.line(x='Q1',y='Total',color='red')
plt.title("Line Graph of Q1")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Many of the students have reached the 10 marks for Q1 in the list of students scored between 30-35 of total marks.

# %%
m.plot.line(x='Q2',y='Total',color='red')
plt.title("Line Graph of Q2")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Many of the students have reached the 10 marks for Q2 in the list of students scored between 30-35 of total marks.

# %%
m.plot.line(x='Q3',y='Total',color='red')
plt.title("Line Graph of Q3")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Only three students have reached the 10 marks for Q3 in the list of students scored between 30-35 of total marks.

# %%
m.plot.line(x='Q4',y='Total',color='red')
plt.title("Line Graph of Q4")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# only one student have reached the 10 marks for Q4 in the list of students scored between 30-35 of total marks.

# %%
m.plot.line(x='Q5',y='Total',color='red')
plt.title("Line Graph of Q5")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Only two students have reached the 10 marks for Q1 in the list of students scored between 30-35 of total marks.

# %%
s['Q1'].plot(kind='pie',subplots=True,figsize=(8,8))
plt.title("Pie Chart of Q1")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Q1')

# %% [markdown]
# The pie chart indicates that how many students have scored marks form 1-7 marks in Q1.

# %%
s['Q2'].plot(kind='pie',subplots=True,figsize=(8,8))
plt.title("Pie Chart of Q2")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Q2')
