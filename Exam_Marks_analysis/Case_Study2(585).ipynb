# %% [markdown]
# # V. ADITYA BHARADWAJ
# # 2211CS010585
# # GROUP 3

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Loading DataSet --> MIDMARKS (excel file)**

# %%
df = pd.read_excel('MIDMARKS.xlsx')
df
# Out:
#      S.NO SECTION  DV  MA  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12   0  17    9  19   15
# 1     2.0   ALPHA  19  12  16   16  18    3
# 2     3.0   ALPHA  18  14  18   18  18   16
# 3     4.0   ALPHA  15   9  19   17  19   15
# 4     5.0   ALPHA  18  17  19   19  20   18
# ..    ...     ...  ..  ..  ..  ...  ..  ...
# 713   NaN    ZETA  19   8   8   19  17   18
# 714   NaN    ZETA  12   1   7   10  20    8
# 715   NaN    ZETA  17   6  14   14  17   18
# 716   NaN    ZETA  12   1   6    7  15   12
# 717   NaN    ZETA  19  14  17   16  20   19
#
# [718 rows x 8 columns]

# %% [markdown]
# **Filling NaN with (0's)**

# %%
df.fillna(0, inplace=True)
df
# Out:
#      S.NO SECTION  DV  MA  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12   0  17    9  19   15
# 1     2.0   ALPHA  19  12  16   16  18    3
# 2     3.0   ALPHA  18  14  18   18  18   16
# 3     4.0   ALPHA  15   9  19   17  19   15
# 4     5.0   ALPHA  18  17  19   19  20   18
# ..    ...     ...  ..  ..  ..  ...  ..  ...
# 713   0.0    ZETA  19   8   8   19  17   18
# 714   0.0    ZETA  12   1   7   10  20    8
# 715   0.0    ZETA  17   6  14   14  17   18
# 716   0.0    ZETA  12   1   6    7  15   12
# 717   0.0    ZETA  19  14  17   16  20   19
#
# [718 rows x 8 columns]

# %% [markdown]
# **'S.NO' type changed to integer**

# %%
df["S.NO"]=df["S.NO"].astype("int64")
df["S.NO"]=range(1,len(df)+1)
df
# Out:
#      S.NO SECTION  DV  MA  PP BEEE  FL FIMS
# 0       1   ALPHA  12   0  17    9  19   15
# 1       2   ALPHA  19  12  16   16  18    3
# 2       3   ALPHA  18  14  18   18  18   16
# 3       4   ALPHA  15   9  19   17  19   15
# 4       5   ALPHA  18  17  19   19  20   18
# ..    ...     ...  ..  ..  ..  ...  ..  ...
# 713   714    ZETA  19   8   8   19  17   18
# 714   715    ZETA  12   1   7   10  20    8
# 715   716    ZETA  17   6  14   14  17   18
# 716   717    ZETA  12   1   6    7  15   12
# 717   718    ZETA  19  14  17   16  20   19
#
# [718 rows x 8 columns]

# %% [markdown]
# **Replacing All AB, MP, A as '0'**

# %%
df = df.replace("A", 0)
df = df.replace("AB", 0)
df = df.replace("MP", 0)

df = df.infer_objects(copy=False) 
df
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_4272\3680241118.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace("A", 0)
# C:\Users\adity\AppData\Local\Temp\ipykernel_4272\3680241118.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace("AB", 0)
# ...

# %% [markdown]
# **Adding a new Column 'Total' for each individual student**

# %%
df["Total"]=df["DV"]+df["MA"]+df["PP"]+df["BEEE"]+df["FL"]+df["FIMS"]
df
# Out:
#      S.NO SECTION  DV  MA  PP  BEEE  FL  FIMS  Total
# 0       1   ALPHA  12   0  17     9  19    15     72
# 1       2   ALPHA  19  12  16    16  18     3     84
# 2       3   ALPHA  18  14  18    18  18    16    102
# 3       4   ALPHA  15   9  19    17  19    15     94
# 4       5   ALPHA  18  17  19    19  20    18    111
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...
# 713   714    ZETA  19   8   8    19  17    18     89
# 714   715    ZETA  12   1   7    10  20     8     58
# 715   716    ZETA  17   6  14    14  17    18     86
# 716   717    ZETA  12   1   6     7  15    12     53
# 717   718    ZETA  19  14  17    16  20    19    105
#
# [718 rows x 9 columns]

# %% [markdown]
# **Obtained By 120 marks actual total**

# %%
df['Obtained By'] = 120
df
# Out:
#      S.NO SECTION  DV  MA  PP  BEEE  FL  FIMS  Total  Obtained By
# 0       1   ALPHA  12   0  17     9  19    15     72          120
# 1       2   ALPHA  19  12  16    16  18     3     84          120
# 2       3   ALPHA  18  14  18    18  18    16    102          120
# 3       4   ALPHA  15   9  19    17  19    15     94          120
# 4       5   ALPHA  18  17  19    19  20    18    111          120
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...          ...
# 713   714    ZETA  19   8   8    19  17    18     89          120
# 714   715    ZETA  12   1   7    10  20     8     58          120
# 715   716    ZETA  17   6  14    14  17    18     86          120
# 716   717    ZETA  12   1   6     7  15    12     53          120
# 717   718    ZETA  19  14  17    16  20    19    105          120
#
# [718 rows x 10 columns]

# %% [markdown]
# **Student's having atleast one '0'**

# %%
subject_columns = ['DV', 'MA', 'PP', 'BEEE', 'FL', 'FIMS']
df['Check_if_0'] = (df[subject_columns] == 0).any(axis = 1)
df
# Out:
#      S.NO SECTION  DV  MA  PP  BEEE  FL  FIMS  Total  Obtained By  Check_if_0
# 0       1   ALPHA  12   0  17     9  19    15     72          120        True
# 1       2   ALPHA  19  12  16    16  18     3     84          120       False
# 2       3   ALPHA  18  14  18    18  18    16    102          120       False
# 3       4   ALPHA  15   9  19    17  19    15     94          120       False
# 4       5   ALPHA  18  17  19    19  20    18    111          120       False
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...          ...         ...
# 713   714    ZETA  19   8   8    19  17    18     89          120       False
# 714   715    ZETA  12   1   7    10  20     8     58          120       False
# 715   716    ZETA  17   6  14    14  17    18     86          120       False
# 716   717    ZETA  12   1   6     7  15    12     53          120       False
# 717   718    ZETA  19  14  17    16  20    19    105          120       False
#
# [718 rows x 11 columns]

# %% [markdown]
# **Backlog Count**

# %%
subject_columns = ['DV', 'MA', 'PP', 'BEEE', 'FL', 'FIMS']  
df['Backlog'] = (df[subject_columns] < 8).sum(axis=1)
df
# Out:
#      S.NO SECTION  DV  MA  PP  BEEE  FL  FIMS  Total  Obtained By  Check_if_0  \
# 0       1   ALPHA  12   0  17     9  19    15     72          120        True
# 1       2   ALPHA  19  12  16    16  18     3     84          120       False
# 2       3   ALPHA  18  14  18    18  18    16    102          120       False
# 3       4   ALPHA  15   9  19    17  19    15     94          120       False
# 4       5   ALPHA  18  17  19    19  20    18    111          120       False
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...          ...         ...
# 713   714    ZETA  19   8   8    19  17    18     89          120       False
# 714   715    ZETA  12   1   7    10  20     8     58          120       False
# 715   716    ZETA  17   6  14    14  17    18     86          120       False
# 716   717    ZETA  12   1   6     7  15    12     53          120       False
# 717   718    ZETA  19  14  17    16  20    19    105          120       False
#
#      Backlog
# 0          1
# ...

# %% [markdown]
# **Failed in all**

# %%
df['Failed_All'] = (df[subject_columns] < 8).all(axis=1)
df
# Out:
#      S.NO SECTION  DV  MA  PP  BEEE  FL  FIMS  Total  Obtained By  Check_if_0  \
# 0       1   ALPHA  12   0  17     9  19    15     72          120        True
# 1       2   ALPHA  19  12  16    16  18     3     84          120       False
# 2       3   ALPHA  18  14  18    18  18    16    102          120       False
# 3       4   ALPHA  15   9  19    17  19    15     94          120       False
# 4       5   ALPHA  18  17  19    19  20    18    111          120       False
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...          ...         ...
# 713   714    ZETA  19   8   8    19  17    18     89          120       False
# 714   715    ZETA  12   1   7    10  20     8     58          120       False
# 715   716    ZETA  17   6  14    14  17    18     86          120       False
# 716   717    ZETA  12   1   6     7  15    12     53          120       False
# 717   718    ZETA  19  14  17    16  20    19    105          120       False
#
#      Backlog  Failed_All
# ...

# %% [markdown]
# **-----------------------------------------------------------------------------------------**

# %% [markdown]
# **All Subject scores are combined together as a column Total**

# %%
def assign_grade(Total):
    if Total >= 110:
        return 'A+'
    elif Total >= 100:
        return 'A'
    elif Total >= 90:
        return 'B'
    elif Total >= 80:
        return 'C'
    elif Total >= 70:
        return 'D'
    elif 50 <= Total <= 60: 
        return 'E'
    else:
        return 'Fail'

df['Grade'] = df['Total'].apply(assign_grade)
df
# Out:
#      S.NO SECTION  DV  MA  PP  BEEE  FL  FIMS  Total  Obtained By  Check_if_0  \
# 0       1   ALPHA  12   0  17     9  19    15     72          120        True
# 1       2   ALPHA  19  12  16    16  18     3     84          120       False
# 2       3   ALPHA  18  14  18    18  18    16    102          120       False
# 3       4   ALPHA  15   9  19    17  19    15     94          120       False
# 4       5   ALPHA  18  17  19    19  20    18    111          120       False
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...          ...         ...
# 713   714    ZETA  19   8   8    19  17    18     89          120       False
# 714   715    ZETA  12   1   7    10  20     8     58          120       False
# 715   716    ZETA  17   6  14    14  17    18     86          120       False
# 716   717    ZETA  12   1   6     7  15    12     53          120       False
# 717   718    ZETA  19  14  17    16  20    19    105          120       False
#
#      Backlog  Failed_All Grade
# ...

# %% [markdown]
# **Grades are assigned to the students total scores**

# %%
df['SECTION'] = df['SECTION'].fillna('SIGMA')  
df['SECTION'] = df['SECTION'].replace('', 'SIGMA')
df['SECTION'] = df['SECTION'].replace(0, 'SIGMA') 
df
# Out:
#      S.NO SECTION  DV  MA  PP  BEEE  FL  FIMS  Total  Obtained By  Check_if_0  \
# 0       1   ALPHA  12   0  17     9  19    15     72          120        True
# 1       2   ALPHA  19  12  16    16  18     3     84          120       False
# 2       3   ALPHA  18  14  18    18  18    16    102          120       False
# 3       4   ALPHA  15   9  19    17  19    15     94          120       False
# 4       5   ALPHA  18  17  19    19  20    18    111          120       False
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...          ...         ...
# 713   714    ZETA  19   8   8    19  17    18     89          120       False
# 714   715    ZETA  12   1   7    10  20     8     58          120       False
# 715   716    ZETA  17   6  14    14  17    18     86          120       False
# 716   717    ZETA  12   1   6     7  15    12     53          120       False
# 717   718    ZETA  19  14  17    16  20    19    105          120       False
#
#      Backlog  Failed_All Grade
# ...

# %% [markdown]
# **Filter the DataFrame for the "ALPHA" section and calculate the total marks for specified subjects.**

# %%
a = df[df["SECTION"] == "ALPHA"].copy()  
a1 = ["DV", "MA", "PP", "BEEE", "FL", "FIMS"]
a["TOTAL"] = a[a1].apply(pd.to_numeric, errors='coerce').sum(axis=1).astype(int)
a
# Out:
#     S.NO SECTION  DV  MA  PP  BEEE  FL  FIMS  Total  Obtained By  Check_if_0  \
# 0      1   ALPHA  12   0  17     9  19    15     72          120        True
# 1      2   ALPHA  19  12  16    16  18     3     84          120       False
# 2      3   ALPHA  18  14  18    18  18    16    102          120       False
# 3      4   ALPHA  15   9  19    17  19    15     94          120       False
# 4      5   ALPHA  18  17  19    19  20    18    111          120       False
# ..   ...     ...  ..  ..  ..   ...  ..   ...    ...          ...         ...
# 85    86   ALPHA   3   4  14    13  18    13     65          120       False
# 86    87   ALPHA  17  18  19    20  20    18    112          120       False
# 87    88   ALPHA  13  17  14    19  15    17     95          120       False
# 88    89   ALPHA   2  17   0     3  15     2     39          120        True
# 89    90   ALPHA  10   6  15    10  15    10     66          120       False
#
#     Backlog  Failed_All Grade  TOTAL
# ...

# %% [markdown]
# **Total data of student scores of ALPHA section is filtered above under a variable "a"**

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=section_means.index, y=section_means.values, hue=section_means.index, palette="magma", legend=False)

plt.title("Average TOTAL Scores by SECTION")
plt.xlabel("SECTION")
plt.ylabel("Average TOTAL Score")

plt.show()

# %% [markdown]
# **Every section consists of total of 90 Students but in the EPSILON section there are only 88 Students**

# %%
above_100 = df[df["Total"] > 100].groupby("SECTION").size()

plt.figure(figsize=(8, 6))
sns.barplot(x=above_100.index, y=above_100.values, hue=above_100.index, palette="magma", legend=False)
plt.title("Number of Students Scoring Above 100 by SECTION")
plt.xlabel("SECTION")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# **Using bar plot, from SIGMA section most number of students has scored 100+ marks where as from EPSILON section less number of students has scored 100+ marks**

# %%
below_50 = df[df["Total"] < 50].groupby("SECTION").size()

plt.figure(figsize=(8, 6))
sns.lineplot(x=below_50.index, y=below_50.values)
plt.title("Number of Students Scoring below 50 by SECTION")
plt.xlabel("SECTION")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# **Using line plot, from GAMMA section most number of students has scored less than 50 marks where as from BETA section less number of students has scored less than 50 marks.**

# %%
plt.figure(figsize=(8, 6))
sns.barplot(data=df, x="SECTION", y="Total", hue="SECTION", palette="coolwarm", legend=False)
plt.title("Distribution of TOTAL Scores by SECTION")
plt.xlabel("SECTION")
plt.ylabel("TOTAL Score")
plt.show()

# %% [markdown]
# **The barplot displays the analysis of the Distribution of TOTAL Scores by each SECTION.**

# %%
correlation_matrix = df[["DV", "MA", "PP", "BEEE", "FL", "FIMS", "Total"]].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap Between Subject Scores")
plt.show()

# %% [markdown]
# **It displays the correlation matrix(heatmap) in between Subject Scores.**

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x="SECTION", y="Total", hue="SECTION", palette="muted", legend=False)
plt.title("Distribution of TOTAL Scores by SECTION")
plt.xlabel("SECTION")
plt.ylabel("TOTAL Score")
plt.show()

# %% [markdown]
# **In this boxplot, both the highest & lowest mark was scored by the students of DELTA Section. The boxplot represents the Maximum and Minimum values**

# %%
grade_counts = df["Grade"].value_counts().reset_index()
grade_counts.columns = ["Grade", "Count"]

plt.figure(figsize=(8, 6))
sns.barplot(data=grade_counts, x="Grade", y="Count", hue="Grade", palette="mako", order=["A+", "A", "B", "C", "D", "F"], legend=False)
plt.title("Count of Students in Each Grade")
plt.xlabel("Grade")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# **Using bar plot, from GAMMA section most number of students has scored less than 50 marks where as from BETA section less number of students has scored less than 50 marks.**

# %%
below_50 = df[df["Total"] < 50].groupby("SECTION").size()

plt.figure(figsize=(8, 6))
sns.stripplot(x=below_50.index, y=below_50.values)
plt.title("Number of Students Scoring below 50 by SECTION")
plt.xlabel("SECTION")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# **Using stripplot, from GAMMA section most number of students has scored less than 50 marks where as from BETA section less number of students has scored less than 50 marks.**

# %%
df_sorted = df.sort_values(by="S.NO")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_sorted, x="S.NO", y="Total", color="blue")
plt.title("Trend of TOTAL Scores by Roll Number")
plt.xlabel("Roll Number")
plt.ylabel("TOTAL Score")
plt.show()

# %% [markdown]
# **The total students marks are plotted as a line graph based on the S.NO and TOTAL Scores.**

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="SECTION", y="DV",)
plt.title("Lineplot of DV Scores by SECTION")
plt.xlabel("SECTION")
plt.ylabel("DV Score")
plt.show()

# %% [markdown]
# **Lineplot of DV Scores by SECTION where the highest mark was by OMEGA Section and Least was by BETA Section**

# %%
total=df["SECTION"].value_counts()
total.plot(kind='pie', figsize=(8, 8),autopct='%1.1f%%', startangle=90)
plt.title("Pie Chart of Total Students in each Section")
plt.show()

# %% [markdown]
# **The above pie chart indicates the count of students in each section.**
